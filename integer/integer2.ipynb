# %%
#Дана масса M в килограммах. Используя операцию деления нацело, найти количество полных тонн в ней (1 тонна = 1000 кг)
M = int(input('Введите массу М в кг: '))
T = M // 1000
print(f'Кол-во тонн в массе равно {T}')
# Out:
# Введите массу М в кг: 849865
# Кол-во тонн в массе равно 849
