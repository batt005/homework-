# %%
#Дано расстояние L в сантиметрах. Используя операцию деления нацело, найти количество полных метров в нем (1 метр = 100 см)
L = int(input('Введите расстояния в см: '))
met = L // 100
print(f'Расстояние равно {met} метров')
# Out:
# Введите расстояния в см: 283789275
# Расстояние равно 2837892 метров
